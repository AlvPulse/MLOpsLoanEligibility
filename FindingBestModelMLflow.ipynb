# %%
import mlflow
import pandas as pd

# %%
from MyPipeline.MLFlow_Config import search_space
from MyPipeline.train_pipeline import train_pipeline_mlflow
mlflow.set_tracking_uri("mysql+pymysql://root:P%40ssw0rd@localhost:3306/db_mlflow")

top_pipe, top_metrics= train_pipeline_mlflow(search_space)
print(top_metrics)
# Out:
# 2025/07/21 13:27:10 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/07/21 13:27:10 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl MySQLImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl MySQLImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# 2025/07/21 13:27:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/21 13:27:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/07/21 13:27:53 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/21 13:27:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# 2025/07/21 13:28:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/21 13:28:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/07/21 13:28:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# top_model_name RandomForest
# top_model Pipeline(steps=[('FeatureEngSelection', feature_eng_selection()),
#                 ('preprocessor', AutoColumnPreprocessor()),
#                 ('model',
#                  RandomForestClassifier(min_samples_split=5,
#                                         n_estimators=200))])
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[2], line 5
#       2 from MyPipeline.train_pipeline import train_pipeline_mlflow
#       3 mlflow.set_tracking_uri("mysql+pymysql://root:P%40ssw0rd@localhost:3306/db_mlflow")
# ----> 5 top_pipe, top_metrics= train_pipeline_mlflow(search_space)
#       6 print(top_metrics)
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\MyPipeline\train_pipeline.py:84, in train_pipeline_mlflow(search_space)
#      82 print("top_model_name",top_model_name)
#      83 print("top_model",top_model)
# ---> 84 mlflow.sklearn.log_model(
#      85     sk_model=top_model,
#      86     artifact_path=best_model_path,
#      87     registered_model_name=f"{top_model_name}Classifier"  # This registers the model!
#      88     # The 'registered_model_name' is the name it will appear under in the Model Registry.
#      89     # If it doesn't exist, MLflow creates it.
#      90     # If it exists, it creates a new version of that model.
#      91 )
#      93 print(f"\n✅ Best model: {top_model_name}")
#      94 print(f"Metrics: {top_metrics}")
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\sklearn\__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)    355     name: Optional[str] = None,
#     356 ):
#     357     """
#     358     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359     containing the following flavors:
#    (...)    424
#     425     """
# --> 426     return Model.log(
#     427         artifact_path=artifact_path,
#     428         name=name,
#     429         flavor=mlflow.sklearn,
#     430         sk_model=sk_model,
#     431         conda_env=conda_env,
#     432         code_paths=code_paths,
#     433         serialization_format=serialization_format,
#     434         registered_model_name=registered_model_name,
#     435         signature=signature,
#     436         input_example=input_example,
#     437         await_registration_for=await_registration_for,
#     438         pip_requirements=pip_requirements,
#     439         extra_pip_requirements=extra_pip_requirements,
#     440         pyfunc_predict_fn=pyfunc_predict_fn,
#     441         metadata=metadata,
#     442         params=params,
#     443         tags=tags,
#     444         model_type=model_type,
#     445         step=step,
#     446         model_id=model_id,
#     447     )
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\models\model.py:1161, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1156 else:
#    1157     params = {
#    1158         **(params or {}),
#    1159         **(client.get_run(run_id).data.params if run_id else {}),
#    1160     }
# -> 1161     model = mlflow.initialize_logged_model(
#    1162         # TODO: Update model name
#    1163         name=name,
#    1164         source_run_id=run_id,
#    1165         model_type=model_type,
#    1166         params={key: str(value) for key, value in params.items()},
#    1167         tags={key: str(value) for key, value in tags.items()}
#    1168         if tags is not None
#    1169         else None,
#    1170     )
#    1171     if (
#    1172         MLFLOW_PRINT_MODEL_URLS_ON_CREATION.get()
#    1173         and is_databricks_uri(tracking_uri)
#    1174         and (workspace_url := get_workspace_url())
#    1175     ):
#    1176         logged_model_url = _construct_databricks_logged_model_url(
#    1177             workspace_url,
#    1178             model.experiment_id,
#    1179             model.model_id,
#    1180             get_workspace_id(),
#    1181         )
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\tracking\fluent.py:2130, in initialize_logged_model(name, source_run_id, tags, params, model_type, experiment_id)
#    2104 @experimental
#    2105 def initialize_logged_model(
#    2106     name: Optional[str] = None,
#    (...)   2111     experiment_id: Optional[str] = None,
#    2112 ) -> LoggedModel:
#    2113     """
#    2114     Initialize a LoggedModel. Creates a LoggedModel with status ``PENDING`` and no artifacts. You
#    2115     must add artifacts to the model and finalize it to the ``READY`` state, for example by calling
#    (...)   2128         A new :py:class:`mlflow.entities.LoggedModel` object with status ``PENDING``.
#    2129     """
# -> 2130     model = _create_logged_model(
#    2131         name=name,
#    2132         source_run_id=source_run_id,
#    2133         tags=tags,
#    2134         params=params,
#    2135         model_type=model_type,
#    2136         experiment_id=experiment_id,
#    2137     )
#    2138     _last_logged_model_id.set(model.model_id)
#    2139     return model
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\tracking\fluent.py:2257, in _create_logged_model(name, source_run_id, tags, params, model_type, experiment_id)
#    2253     experiment_id = _get_experiment_id() or (
#    2254         get_run(source_run_id).info.experiment_id if source_run_id else None
#    2255     )
#    2256 resolved_tags = context_registry.resolve_tags(tags)
# -> 2257 return MlflowClient().create_logged_model(
#    2258     experiment_id=experiment_id,
#    2259     name=name,
#    2260     source_run_id=source_run_id,
#    2261     tags=resolved_tags,
#    2262     params=params,
#    2263     model_type=model_type,
#    2264 )
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\tracking\client.py:5371, in MlflowClient.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type)
#    5344 @experimental
#    5345 def create_logged_model(
#    5346     self,
#    (...)   5352     model_type: Optional[str] = None,
#    5353 ) -> LoggedModel:
#    5354     """
#    5355     Create a new logged model.
#    5356
#    (...)   5369         The created model.
#    5370     """
# -> 5371     return self._tracking_client.create_logged_model(
#    5372         experiment_id, name, source_run_id, tags, params, model_type
#    5373     )
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:824, in TrackingServiceClient.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type)
#     815 def create_logged_model(
#     816     self,
#     817     experiment_id: str,
#    (...)    822     model_type: Optional[str] = None,
#     823 ) -> LoggedModel:
# --> 824     return self.store.create_logged_model(
#     825         experiment_id=experiment_id,
#     826         name=name,
#     827         source_run_id=source_run_id,
#     828         tags=[LoggedModelTag(str(key), str(value)) for key, value in tags.items()]
#     829         if tags is not None
#     830         else tags,
#     831         params=[LoggedModelParameter(str(key), str(value)) for key, value in params.items()]
#     832         if params is not None
#     833         else params,
#     834         model_type=model_type,
#     835     )
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\store\tracking\sqlalchemy_store.py:1756, in SqlAlchemyStore.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type)
#    1747 def create_logged_model(
#    1748     self,
#    1749     experiment_id: str,
#    (...)   1754     model_type: Optional[str] = None,
#    1755 ) -> LoggedModel:
# -> 1756     _validate_logged_model_name(name)
#    1757     with self.ManagedSessionMaker() as session:
#    1758         experiment = self.get_experiment(experiment_id)
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\mlflow\utils\validation.py:658, in _validate_logged_model_name(name)
#     656 bad_chars = ("/", ":", ".", "%", '"', "'")
#     657 if not name or any(c in name for c in bad_chars):
# --> 658     raise MlflowException(
#     659         f"Invalid model name ({name!r}) provided. Model name must be a non-empty string "
#     660         f"and cannot contain the following characters: {bad_chars}",
#     661         INVALID_PARAMETER_VALUE,
#     662     )
#
# MlflowException: Invalid model name ('MyPipeline/trained_models/RandomForest.pkl') provided. Model name must be a non-empty string and cannot contain the following characters: ('/', ':', '.', '%', '"', "'")
