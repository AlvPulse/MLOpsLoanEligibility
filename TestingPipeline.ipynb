# %%
from MyPipeline.train_pipeline import train_pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
pipeline,metrics=train_pipeline(model)
print(metrics)
# Out:
# {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1_score': 1.0}

# %%
pipeline.predict()

# %%
from MyPipeline.PreProcessing import SkewHandlerTH,AutoColumnPreprocessor
A=SkewHandlerTH()
B= AutoColumnPreprocessor()

# %%
import pandas as pd
df= pd.read_csv('MyPipeline/DataSet/loan_approval_dataset.csv')

# %%
probably_skewed_columns = [' commercial_assets_value', ' luxury_assets_value', ' bank_asset_value',' residential_assets_value', ' loan_amount']
A.fit(df[probably_skewed_columns])
# Out:
# SkewHandlerTH()

# %%
B.fit(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File G:\Users\Alvandian\Documents\GitHub\MLFlow\.venv\Lib\site-packages\sklearn\utils\_repr_html\base.py:149, in ReprHTMLMixin._repr_mimebundle_(self, **kwargs)
#     147 def _repr_mimebundle_(self, **kwargs):
#     148     """Mime bundle used by jupyter kernels to display estimator"""
# --> 149     output = {"text/plain": repr(self)}
#     150     if get_config()["display"] == "diagram":
#     151         output["text/html"] = self._html_repr()
#
# ...
